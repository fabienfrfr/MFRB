# %% [markdown]
# # Notes Quinquennat Mouvement Français pour un Revenu de Base (MFRB)
#
# *Auteur : Fabien Furfaro*
#
# ## Objectif du Rapport
# Le rapport vise à démontrer la faisabilité d’un revenu de base universel selon la charte du MFRB, dans la perspective du quinquennat 2027-2032.
# Il constitue un outil stratégique de plaidoyer et de communication à destination des forces politiques et de la société civile en vue des élections de 2027.
#
# ---
#
# # 1. Contexte et Finalité
#
# - Le revenu de base est une mesure d’**émancipation sociale et économique**, inscrite comme droit fondamental.
# - Le rapport fournit :
#   - une **synthèse critique** des travaux académiques,
#   - des **scénarios socio-fiscaux chiffrés** sur 5 ans,
#   - une **modélisation redistributive**,
#   - une analyse de la **compatibilité avec les politiques publiques existantes**.
#
# ---
#
# # 2. Définition du Revenu de Base (AUE)
#
# ## Caractéristiques
# - **Inaliénable** : non saisissable, non révocable.
# - **Inconditionnel** : aucune exigence de travail ou de recherche d’emploi.
# - **Cumulable** avec tout autre revenu.
# - **Universel & permanent** : versé à toute personne, de la naissance à la mort.
# - **Individuel** : indépendant du foyer.
# - **Sans condition de ressources**.
# - **Ajusté démocratiquement** dans son financement et son montant.
#
# ## Principes
# L’Allocation Universelle d’Existence (AUE) doit :
# - Lutter contre la pauvreté et la précarité.
# - Réduire les inégalités par une redistribution juste.
# - Accompagner la transition écologique.
# - Être inclusive (tous les domiciliés fiscaux en France).
# - Émanciper les individus et renforcer leur autonomie.
# - Favoriser l’emploi choisi et le partage du temps de travail.
# - Consolider la protection sociale existante en l’améliorant.

# %% [markdown]
# # 3 - Analyse des données économiques et sociales en France (2025)
#
# ## Problématique
#
# **Comment mesurer les effets de l’implémentation d’un revenu de base (Allocation Universelle d’Existence – AUE) sur les dépenses publiques ?**
#
# Pour répondre à cette question, il est indispensable de disposer de données détaillées sur :
#
# - La répartition des revenus selon l’âge, la catégorie sociale et la composition des ménages.
# - L’évolution des dépenses et recettes publiques (budgets, aides sociales).
#
# L’objectif est d’évaluer l’impact de l’introduction d’un revenu de base sur le pouvoir d’achat des Français en comparaison avec le système actuel de redistribution basé sur le foyer fiscal, afin d’analyser les effets d’une individualisation des aides.
#
# ***
#
# ## Contexte financier 2025 : dépenses sociales (en milliards d’euros)
#
# | Aide / prestation | Montant (Md€) |
# | :-- | :-- |
# | RSA (Revenu de Solidarité Active, hors MPI) | 11 |
# | Pensions de retraite (PA) | 10,2 |
# | Allocation de Solidarité Spécifique (ASS) | 2 |
# | Aides au logement (APL, ALS, ALF) | 15,6 |
# | Allocation de Solidarité aux Personnes Âgées (ASPA) | 3,8 |
# | Allocations Familiales (AF), Complément Familial (CF), Allocation PAJE | 19,8 |
# | Allocation de Soutien Familial (ASF) + Majoration Parent Isolé (MPI) | 2,6 |
# | Bourses critère social | 2,4 |
# | Quotient conjugal | 12 |
# | Quotient familial | 17 |
# | **Total estimé** | **60** |
#
# *Sources : [INSEE analyse des dépenses sociales 2024-2025, rapports DGFiP et Cour des Comptes.](https://www.insee.fr/fr/statistiques/8574492)*
#
# ***
#
# ## Vers une redistribution transformante, horizontale et inclusive avec l’AUE
#
# ### Principes
#
# - Chaque individu reçoit une Allocation Universelle d’Existence (AUE), un revenu de base individuel.
# - Chaque individu contribue selon ses revenus (Contribution à l’AUE – CAUE) et son patrimoine (Taxe sur l’Actif Net – TAN).
# - Ce système remplace la redistribution actuelle majoritairement basée sur le foyer fiscal par une redistribution horizontale et individualisée.
#
#
# ### Formules clés
#
# - **Revenu avant redistribution** :
#
# $$
# R = R_{\text{activité}} + R_{\text{patrimoine}}
# $$
# - **Revenu après redistribution** :
#
# $$
# RN = R + \left( AUE_{n+1} - CR_n - \frac{TAN_{a-1}}{12} \right)
# $$
#
# avec :
#
# - CR = cotisations sociales
# - TAN = taxe sur le patrimoine mensuelle
#
#
# ### Impact budgétaire estimé
#
# - Le système assure un **coût net nul** pour l’État, car l’AUE remplace les aides sociales actuelles totalisant environ **138 milliards €** en 2025.
# - Le financement repose notamment sur les recettes actuelles de l’impôt sur le revenu et de l’Impôt sur la Fortune Immobilière (IFI), représentant environ **117 milliards €**.
# - Le modèle simplifie la redistribution sociale, qui est aujourd’hui complexe et couteuse.
# - Environ 10% des foyers fiscaux verraient leur contribution augmenter, pour une somme inférieure à 50 milliards €, soit environ 8% des coûts actuels de redistribution.
#
#
# ### Bénéfices sociaux et économiques
#
# - Allègement significatif de la charge sur le régime de retraite par répartition.
# - Facilitation d’une assurance maladie universelle intégrale, sans accroissement des cotisations sociales des salariés ni des employeurs.
# - Progrès vers une véritable sécurité sociale universelle, conforme à ses principes fondateurs.
#
# ***
#
# ## Objectif analytique
#
# Créer un tableau de synthèse intégrant les données suivantes :
#
#
# | Type de données | Description |
# | :-- | :-- |
# | **Entrées** | Revenus par âge, par catégorie sociale, et par ménage |
# | **Sorties** | - Dépenses publiques sans revenu de base (rdb) <br> - Dépenses publiques avec rdb <br> - Gains sociaux via pouvoir d’achat accru |
#
# Ce tableau permettra de mesurer précisément :
#
# - L’impact budgétaire net de l’introduction de l’AUE.
# - Le gain global en pouvoir d’achat sur la population.
# - Les effets redistributifs horizontaux et verticaux.
#
# ***
#
# ## Données économiques et sociales clés (2025)
#
# | Indicateurs | Valeurs | Sources principales |
# | :-- | :-- | :-- |
# | **Salaire moyen net secteur privé** | ~2 735 € / mois | INSEE, Revenus et niveaux de vie 2021 ([source](https://www.insee.fr/fr/statistiques/5371205)) |
# | **Salaire médian net** | ~2 183 € / mois | Idem |
# | **Revenu disponible brut (T1 2025)** | +0,7% en glissement annuel | INSEE, Revenu disponible et pouvoir d'achat ([source](https://www.insee.fr/fr/statistiques/2830166)) |
# | **Pouvoir d’achat (T1 2025)** | +0,2% | Idem |
# | **Seuil de pauvreté** (personne seule) | ~1 073 € / mois | INSEE, Seuils de pauvreté 2021 ([source](https://www.insee.fr/fr/statistiques/5759045)) |
# | **Seuil de pauvreté** (famille monoparentale) | ~1 395 € / mois | Idem |
# | **Niveau de vie médian (2023)** | ~2 147 € nets / mois | INSEE, Revenus types des ménages ([source](https://www.insee.fr/fr/statistiques/2413763)) |
# | **Taux de chômage (2025)** | ~7,4% | INSEE, Emploi et chômage 2025 ([source](https://www.insee.fr/fr/statistiques/2381414)) |
# | **Croissance dépenses publiques 2024** | +2,7% | INSEE Analyse dépense publique ([source](https://www.insee.fr/fr/statistiques/8574492)) |
#
#
# ***
#
# ## Sources principales de données publiques
#
# ### Données démographiques
#
# - Évolution et structure de la population (2013)
# INSEE [web officielle](https://www.insee.fr/fr/statistiques/2044751)
# Fichier Excel [ici](https://www.insee.fr/fr/statistiques/fichier/2044751/base-cc-evol-struct-pop-2013.zip)
# - Population des 16 ans et plus selon diplôme, sexe et âge (1968-2021)
# INSEE [web officielle](https://www.insee.fr/fr/statistiques/1893149)
# Fichier Excel [ici](https://www.insee.fr/fr/statistiques/fichier/1893149/pop-16ans-dipl6821.zip)
# - Revenus et pauvreté des ménages (2013)
# INSEE [web officielle](https://www.insee.fr/fr/statistiques/2044751)
# Fichier Excel [ici](https://www.insee.fr/fr/statistiques/fichier/2388572/filo-revenu-pauvrete-menage-2013.zip)
# - Composition des ménages (2021)
# INSEE [web officielle](https://www.insee.fr/fr/statistiques/5039855)
# Fichier Excel [ici](https://www.insee.fr/fr/statistiques/fichier/5039855/FET2021-2.xlsx)
#
#
# ### Données économiques et sociales
#
# - Revenus et niveaux de vie (2021) : [INSEE Revenus et niveaux de vie 2021](https://www.insee.fr/fr/statistiques/5371205)
# - Évolution du revenu disponible et pouvoir d’achat (2025) : [Source INSEE](https://www.insee.fr/fr/statistiques/2830166)
# - Seuils de pauvreté (2021) : [INSEE](https://www.insee.fr/fr/statistiques/5759045)
# - Niveau de vie médian (2023) : [INSEE](https://www.insee.fr/fr/statistiques/2413763)
# - Analyse des dépenses publiques (2024-2025) : [INSEE Analyse dépenses publiques](https://www.insee.fr/fr/statistiques/8574492)
# - Emploi et chômage (2025) : [INSEE Emploi \& Chômage](https://www.insee.fr/fr/statistiques/2381414)
#
# ***
#
# ## Tableaux de bord économiques et sociaux en ligne
#
# Pour un suivi dynamique des indicateurs, INSEE propose :
#
# - **Tableau des revenus, niveaux de vie et pouvoir d'achat**
# [Tableau de bord INSEE](https://www.insee.fr/fr/outil-interactif/5367857/tableau/30_RPC/31_RNP)
# - **Tableau de bord de l’économie française**
# [Tableau de bord INSEE](https://www.insee.fr/fr/outil-interactif/5367857/tableau/10_ECC/15_FIN)
# - **Dépenses publiques et recettes**
# [INSEE Dépense Publique](https://www.insee.fr/fr/statistiques/2381414)
# - **Analyse détaillée des dépenses publiques**
# Fichier XLS : [IP2054.xlsx (INSEE)](https://www.insee.fr/fr/statistiques/fichier/8574492/IP2054.xlsx)

# %%
# Out:
# Chargement de 'revenus_niveaux_vie_2021' depuis https://www.insee.fr/fr/statistiques/fichier/5371205/RPM2021-F3.xlsx ...
# 'revenus_niveaux_vie_2021' chargé avec succès avec 4 feuilles : ['figure 1', 'figure 2', 'figure 3', 'figure 4 ']
# Chargement de 'revenu_disponible_pouvoir_achat' depuis https://www.insee.fr/fr/statistiques/fichier/2830166/reve-niv-vie-pouv-achat-trim.xlsx ...
# 'revenu_disponible_pouvoir_achat' chargé avec succès avec 2 feuilles : ['Données', 'travail-prévisu']
# Chargement de 'revenus_menages_types' depuis https://www.insee.fr/fr/statistiques/fichier/2413763/reve-niv-vie-menage-type-compo.xlsx ...
# 'revenus_menages_types' chargé avec succès avec 1 feuilles : ['Données']
# Chargement de 'depense_publique' depuis https://www.insee.fr/fr/statistiques/fichier/8574492/IP2054.xlsx ...
# 'depense_publique' chargé avec succès avec 7 feuilles : ['Sommaire', 'Figure 1', 'Figure 2', 'Figure 3', 'Figure 4', 'Figure 5', 'Figure Encadré']
# ...

# %% [markdown]
# #### à partir des données regroupée par Guy Valette
#
# Pour l'instant, donnée brouillons non vérifié

# %%
# Out:
# Moyenne AUE mensuelle par ménage selon compos. types : 1726.50 €
# Moyenne UC pondérée dans la population : 2.22 UC
# AUE moyenne par UC globale estimée : 778.40 € / mois
#
# --- Redistribution comparée par décile (sans vs avec AUE) ---
#
#     decile   UC  RevenuBrut  RevenuNet  RevDisponible_INSEE  AidesSociales  \
# 0     <10% 1.10           0       0.00                  900            900
# 1   10-20% 1.15         615     481.55                 1331            850
# 2   20-30% 1.21        1455    1139.27                 1639            500
# 3   30-40% 1.34        2035    1593.41                 1973            420
# 4   40-50% 1.46        2670    2090.61                 2345            325
# 5   50-60% 1.59        3360    2630.88                 2780            250
# 6   60-70% 1.69        4100    3210.30                 3270            210
# 7   70-80% 1.82        5120    4009.00                 3970            180
# ...

# %% [markdown]
# ## Suppléments
#
# Pour aller plus loins dans les données par catégorie socioprofessionnel etc.

# %% [markdown]
# ---
#
# # 4. Scénarios de Mise en Place (2027-2032)
#
# ## Année 1 : Allocations familiales & Impôt sur le revenu
# - Allocations universelles dès le **1er enfant** (350 €/mois de 0-14 ans, 500 € pour 14-18 ans, +1800 € à la naissance).
# - Réforme fiscale : individualisation de l’impôt, fin du quotient familial.
# - **Coût estimé** : 76 Mds €, financés par économies et refonte IR.
#
# ## Année 2 : Revenu d’autonomie jeunesse
# - Jeunes 18-25 ans : **800 €/mois** (dotation tremplin).
# - Capital de **67 200 €** disponible à 25 ans.
# - **Coût** : 54 Mds €.
# - Financement : Taxe sur l’Actif Net (TAN), réforme de l’IFI.
#
# ## Année 3 : Retraite universelle
# - Instaurer une **retraite de base de 1000 €/mois** pour tous.
# - Financement :
#   - TAN portée à 2 %,
#   - Cotisation AUE (CAUE) pour retraités (30 %),
#   - Suppression ASPA et aides actuelles.
#
# ## Année 4 : Généralisation du revenu de base
# - AUE attribué à tous.
# - Suppression de l’IR et des minima sociaux.
# - CAF → **Caisse AUE**,
# - URSSAF → collecte de CAUE + TAN.
# - Assurance maladie universelle à 100 %.
#
# ---
#
# # 4. Financement
#
# - **Cotisation AUE (CAUE)** : sur revenus (progressif jusqu’à 30 %).
# - **Taxe sur l’Actif Net (TAN)** : 0–2 % annuel sur patrimoine net (≈ 14 567 Md€).
# - **Contribution sur la Valeur Ajoutée (C.VA)** : 3,3 % sur VA marchande.
#
# ➡️ **Redistribution interne** : ne coûte **rien au budget de l’État**.
#
# ---
#
# # 5. Simulation d’Impact Redistributif
#
# ## Montants par Âge
# - Naissance : 1800 €
# - 0–14 ans : 350 €/mois
# - 14–18 ans : 500 €/mois
# - 18–25 ans : 800 €/mois
# - 25–60 ans : 1000 €/mois
# - 60+ ans : 1000 €/mois
# - Décès : 4800 €
#
# ➡️ Montant moyen = **856 €/mois** sur une espérance de vie de 83 ans.
#
# ## Exemples de gains/pertes
# - Personne seule sans ressource : **+137 €/mois**.
# - Demi-SMIC : **+404 €/mois**.
# - SMIC : **+239 €/mois**.
# - Maman solo avec 2 enfants : **+656 €/mois**.
# - Couple de retraités modestes : **+1007 €/mois** (+64 %).
# - Famille classe moyenne (2 SMICs) : **+719 €/mois** (+20 %).
# - Famille aisée : **–268 €/mois** (–3 %).
#
# ---
#
# # 6. Redistribution : Comparaison des Modèles
#
# ## Redistribution verticale (système actuel)
# - Fonctionne comme une **charité conditionnée**.
# - Crée une fracture entre "bénéficiaires" et "contributeurs".
# - Coûte cher : **138 Mds d’aides sociales** pour **117 Mds de recettes IR+IFI** (déficit 21 Mds).
#
# ## Redistribution horizontale (AUE)
# - **Universelle et inclusive** : tous sont bénéficiaires et contributeurs.
# - Organisée via la **Caisse AUE**.
# - Supprime les aides conditionnées.
# - Garantit une authentique **Sécurité sociale universelle**.
# - Ne génère **aucun coût supplémentaire pour l’État**.
#
# ---
